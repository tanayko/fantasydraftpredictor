# %%
import pandas as pd
import os

file_path = os.path.join('basic_data_csv', 'Game_Logs_Quarterback.csv')
qb_data = pd.read_csv(file_path)
brady_data = qb_data[qb_data['Name'] == 'Brady, Tom'].head(15)
brady_data
# Out:
#               Player Id        Name Position  Year          Season  Week  \
# 10589  tombrady/2504211  Brady, Tom       QB  2016       Preseason     1
# 10590  tombrady/2504211  Brady, Tom       QB  2016       Preseason     2
# 10591  tombrady/2504211  Brady, Tom       QB  2016       Preseason     3
# 10592  tombrady/2504211  Brady, Tom       QB  2016       Preseason     4
# 10593  tombrady/2504211  Brady, Tom       QB  2016  Regular Season     5
# 10594  tombrady/2504211  Brady, Tom       QB  2016  Regular Season     6
# 10595  tombrady/2504211  Brady, Tom       QB  2016  Regular Season     7
# 10596  tombrady/2504211  Brady, Tom       QB  2016  Regular Season     8
# 10597  tombrady/2504211  Brady, Tom       QB  2016  Regular Season    10
# 10598  tombrady/2504211  Brady, Tom       QB  2016  Regular Season    11
# 10599  tombrady/2504211  Brady, Tom       QB  2016  Regular Season    12
# 10600  tombrady/2504211  Brady, Tom       QB  2016  Regular Season    13
# ...
