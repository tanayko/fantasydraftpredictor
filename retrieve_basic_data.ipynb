# %%
import pandas as pd
import os

file_path = os.path.join('basic_data_csv', 'Game_Logs_Quarterback.csv')
qb_data = pd.read_csv(file_path)
brady_data = qb_data[(qb_data['Name'] == 'Brady, Tom') & (qb_data['Year'] == 2004)].head(15)

brady_data
# Out:
#               Player Id        Name Position  Year          Season  Week  \
# 10840  tombrady/2504211  Brady, Tom       QB  2004  Regular Season     1
# 10841  tombrady/2504211  Brady, Tom       QB  2004  Regular Season     2
# 10842  tombrady/2504211  Brady, Tom       QB  2004  Regular Season     4
# 10843  tombrady/2504211  Brady, Tom       QB  2004  Regular Season     5
# 10844  tombrady/2504211  Brady, Tom       QB  2004  Regular Season     6
# 10845  tombrady/2504211  Brady, Tom       QB  2004  Regular Season     7
# 10846  tombrady/2504211  Brady, Tom       QB  2004  Regular Season     8
# 10847  tombrady/2504211  Brady, Tom       QB  2004  Regular Season     9
# 10848  tombrady/2504211  Brady, Tom       QB  2004  Regular Season    10
# 10849  tombrady/2504211  Brady, Tom       QB  2004  Regular Season    11
# 10850  tombrady/2504211  Brady, Tom       QB  2004  Regular Season    12
# 10851  tombrady/2504211  Brady, Tom       QB  2004  Regular Season    13
# ...

# %%
file_path = os.path.join('official_2024_fantasy_rankings', 'Sleeper_Standard.csv')
sleeper_data = pd.read_csv(file_path)
sleeper_data.head()
# Out:
#    Unnamed: 0                 Name Team  BYE Pos  ADP  FantasyPros  \
# 0         NaN  Christian McCaffrey   SF    9  RB    1            1
# 1         NaN          Tyreek Hill  MIA    6  WR    2            3
# 2         NaN          CeeDee Lamb  DAL    7  WR    2            2
# 3         NaN     Justin Jefferson  MIN    6  WR    4            5
# 4         NaN        Ja'Marr Chase  CIN   12  WR    7            4
#
#    SleeperRank  SleepvADP  SleepvFP  Round  Pick
# 0            1       0.00      0.00    1.0     1
# 1            2       0.00     -0.33    NaN     2
# 2            3       0.50      0.50    NaN     3
# 3            4       0.00     -0.20    NaN     4
# 4            5      -0.29      0.25    NaN     5
